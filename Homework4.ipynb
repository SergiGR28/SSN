# %% [markdown]
# <a href="https://colab.research.google.com/github/SergiGR28/SSN/blob/main/Homework4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Introduccio al metode montecarlo
#Model Ising 1D
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

H=2 #Camp magnetic
J=-1 #Spin

#Generation of a random initial state for N spins
def initialstate(N):
    ''' generates a random spin configuration for initial condition'''
    state = 2*np.random.randint(2, size=N)-1
    return state

#Definim les interaccions i les solucions del model
def mcmove(config, beta):
    '''Monte Carlo move using Metropolis algorithm '''
    for i in range(N):
                #select random spin from N system
                a = np.random.randint(0, N)
                s =  config[a]
                #calculate energy cost of this new configuration (the % is for calculation of periodic boundary condition)
                nb = config[(a+1)%N] + config[(a-1)%N]
                cost = 2*s*(J*nb+H)
                #flip spin or not depending on the cost and its Boltzmann factor
                ## (acceptance probability is given by Boltzmann factor with beta = 1/kBT
                if cost < 0:
                    s *= -1
                elif rand() < np.exp(-cost*beta):
                    s *= -1
                config[a] = s
    return config

#This function calculates the energy of a given configuration for the plots of Energy as a function of T
def calcEnergy(config):
    '''Energy of a given configuration'''
    energy = 0
    for i in range(len(config)):
            S = config[i]
            nb = config[(i+1)%N]
            energy += -J*nb*S-S*H
    return energy

#This function calculates the magnetization of a given configuration
def calcMag(config):
    '''Magnetization of a given configuration'''
    mag = np.sum(config)
    return mag

#
# MAIN PROGRAM
#
# Initial parameters for calculation
## change the parameter below if you want to simulate a smaller system
nt      = 2**8        # number of temperature points
N       = 2**4        # size of the lattice, N x N
eqSteps = 2**10       # number of MC sweeps for equilibration
mcSteps = 2**10       # number of MC sweeps for calculation

n1, n2  = 1.0/(mcSteps*N), 1.0/(mcSteps*mcSteps*N)
#Generate a random distribution of temperatures to make an exploration
tm = 2.269;    T=np.random.normal(tm, .64, nt)
T  = T[(T>1.2) & (T<3.8)];    nt = np.size(T)

Energy       = np.zeros(nt);   Magnetization  = np.zeros(nt)
SpecificHeat = np.zeros(nt);   Susceptibility = np.zeros(nt)


#----------------------------------------------------------------------
#  SIMULATION LOOP
#----------------------------------------------------------------------
print('Starting Simulations at ',len(T),' different temperatures.')
for m in range(len(T)):
    E1 = M1 = E2 = M2 = 0
    config = initialstate(N)
    iT=1.0/T[m]
    iT2=iT*iT
    print('Simulation ',m+1,' of',len(T),' at reduced temperature T=',T[m])

    for i in range(eqSteps):         # equilibrate
        mcmove(config, iT)           # Monte Carlo moves

    for i in range(mcSteps):
        mcmove(config, iT)
        Ene = calcEnergy(config)     # calculate the energy
        Mag = calcMag(config)        # calculate the magnetisation

        E1 = E1 + Ene
        M1 = M1 + Mag
        M2 = M2 + Mag*Mag
        E2 = E2 + Ene*Ene

        Energy[m]         = n1*E1
        Magnetization[m]  = n1*M1
        SpecificHeat[m]   = (n1*E2 - n2*E1*E1)*iT2
        Susceptibility[m] = (n1*M2 - n2*M1*M1)*iT

#
# Plot everything
#

f = plt.figure(figsize=(18, 10)); # plot the calculated values

sp =  f.add_subplot(2, 2, 1 );
plt.plot(T, Energy, 'o', color="#A60628");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Energy ", fontsize=20);

sp =  f.add_subplot(2, 2, 2 );
plt.plot(T, abs(Magnetization), 'o', color="#348ABD");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Magnetization ", fontsize=20);

sp =  f.add_subplot(2, 2, 3 );
plt.plot(T, SpecificHeat, 'o', color="#A60628");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Specific Heat ", fontsize=20);

sp =  f.add_subplot(2, 2, 4 );
plt.plot(T, Susceptibility, 'o', color="#348ABD");
plt.xlabel("Temperature (T)", fontsize=20);
plt.ylabel("Susceptibility", fontsize=20);
plt.show()
# Out:
# Starting Simulations at  237  different temperatures.
# Simulation  1  of 237  at reduced temperature T= 2.970792625527701
# Simulation  2  of 237  at reduced temperature T= 1.7026216827390923
# Simulation  3  of 237  at reduced temperature T= 3.054876257114677
# Simulation  4  of 237  at reduced temperature T= 2.4333987766554435
# Simulation  5  of 237  at reduced temperature T= 2.579321126254766
# Simulation  6  of 237  at reduced temperature T= 1.452179232541615
# Simulation  7  of 237  at reduced temperature T= 2.5278742097508275
# Simulation  8  of 237  at reduced temperature T= 2.556663007932437
# Simulation  9  of 237  at reduced temperature T= 1.6777524771448222
# Simulation  10  of 237  at reduced temperature T= 1.5752518366884285
# Simulation  11  of 237  at reduced temperature T= 2.2693142926012495
# Simulation  12  of 237  at reduced temperature T= 1.2038085009329853
# Simulation  13  of 237  at reduced temperature T= 1.5259166082945639
# Simulation  14  of 237  at reduced temperature T= 3.6983207255961563
# Simulation  15  of 237  at reduced temperature T= 1.254839832897921
# Simulation  16  of 237  at reduced temperature T= 2.7250253045690593
# Simulation  17  of 237  at reduced temperature T= 1.6143227997399108
# Simulation  18  of 237  at reduced temperature T= 1.8928778060283173
# Simulation  19  of 237  at reduced temperature T= 3.0758151391362865
# Simulation  20  of 237  at reduced temperature T= 1.5128527338117306
# Simulation  21  of 237  at reduced temperature T= 3.0192189298437446
# Simulation  22  of 237  at reduced temperature T= 2.5958699783767942
# Simulation  23  of 237  at reduced temperature T= 2.6720545050170688
# Simulation  24  of 237  at reduced temperature T= 2.7011250257820367
# Simulation  25  of 237  at reduced temperature T= 2.6565537250756988
# Simulation  26  of 237  at reduced temperature T= 2.9483472940674793
# Simulation  27  of 237  at reduced temperature T= 2.928482263160589
# Simulation  28  of 237  at reduced temperature T= 2.0585938522278906
# Simulation  29  of 237  at reduced temperature T= 3.0943430945682904
# Simulation  30  of 237  at reduced temperature T= 2.246238558249084
# Simulation  31  of 237  at reduced temperature T= 2.201162463195529
# Simulation  32  of 237  at reduced temperature T= 3.2500320237766083
# Simulation  33  of 237  at reduced temperature T= 3.75435780029493
# Simulation  34  of 237  at reduced temperature T= 2.276083180736839
# Simulation  35  of 237  at reduced temperature T= 1.281578191267298
# Simulation  36  of 237  at reduced temperature T= 2.2973630755140517
# Simulation  37  of 237  at reduced temperature T= 2.607885647897505
# Simulation  38  of 237  at reduced temperature T= 2.8557596037348025
# Simulation  39  of 237  at reduced temperature T= 1.705410159519926
# Simulation  40  of 237  at reduced temperature T= 2.215697390670312
# Simulation  41  of 237  at reduced temperature T= 2.0601127967409973
# Simulation  42  of 237  at reduced temperature T= 2.051803218135203
# Simulation  43  of 237  at reduced temperature T= 2.6167092560399667
# Simulation  44  of 237  at reduced temperature T= 1.6467996465057242
# Simulation  45  of 237  at reduced temperature T= 2.66255539937884
# Simulation  46  of 237  at reduced temperature T= 1.9552758327456394
# Simulation  47  of 237  at reduced temperature T= 3.2203675408682093
# Simulation  48  of 237  at reduced temperature T= 1.8907802784857342
# Simulation  49  of 237  at reduced temperature T= 2.722522246491436
# Simulation  50  of 237  at reduced temperature T= 2.1959375228502336
# Simulation  51  of 237  at reduced temperature T= 1.763691334146274
# Simulation  52  of 237  at reduced temperature T= 2.1183981744337617
# Simulation  53  of 237  at reduced temperature T= 1.9236398244896291
# Simulation  54  of 237  at reduced temperature T= 1.304033695849132
# Simulation  55  of 237  at reduced temperature T= 3.044597065916238
# Simulation  56  of 237  at reduced temperature T= 2.6112858783383204
# Simulation  57  of 237  at reduced temperature T= 2.791164140909415
# Simulation  58  of 237  at reduced temperature T= 2.655329376681075
# Simulation  59  of 237  at reduced temperature T= 1.6942237292889883
# Simulation  60  of 237  at reduced temperature T= 2.7924873541391704
# Simulation  61  of 237  at reduced temperature T= 2.5943537291218934
# Simulation  62  of 237  at reduced temperature T= 2.6954282970358916
# Simulation  63  of 237  at reduced temperature T= 2.8920755823754583
# Simulation  64  of 237  at reduced temperature T= 1.4648185655312185
# Simulation  65  of 237  at reduced temperature T= 2.170738568393857
# Simulation  66  of 237  at reduced temperature T= 2.524167742777591
# Simulation  67  of 237  at reduced temperature T= 3.275447840678299
# Simulation  68  of 237  at reduced temperature T= 3.4114270142607266
# Simulation  69  of 237  at reduced temperature T= 2.8731122876978668
# Simulation  70  of 237  at reduced temperature T= 2.5951348918493395
# Simulation  71  of 237  at reduced temperature T= 2.7127950197589956
# Simulation  72  of 237  at reduced temperature T= 1.5869532939543334
# Simulation  73  of 237  at reduced temperature T= 1.968427634649265
# Simulation  74  of 237  at reduced temperature T= 2.0386609315785593
# Simulation  75  of 237  at reduced temperature T= 1.8352996491399625
# Simulation  76  of 237  at reduced temperature T= 2.5257141839426556
# Simulation  77  of 237  at reduced temperature T= 2.33655538806546
# Simulation  78  of 237  at reduced temperature T= 1.9216050081779563
# Simulation  79  of 237  at reduced temperature T= 1.8329880254102076
# Simulation  80  of 237  at reduced temperature T= 1.2115947437827448
# Simulation  81  of 237  at reduced temperature T= 2.7511380628697584
# Simulation  82  of 237  at reduced temperature T= 1.8291180498159514
# Simulation  83  of 237  at reduced temperature T= 1.8356525915103779
# Simulation  84  of 237  at reduced temperature T= 1.920663098235067
# Simulation  85  of 237  at reduced temperature T= 2.9564400755734597
# Simulation  86  of 237  at reduced temperature T= 2.423793891017818
# Simulation  87  of 237  at reduced temperature T= 2.380575358056516
# Simulation  88  of 237  at reduced temperature T= 2.584963922721313
# Simulation  89  of 237  at reduced temperature T= 2.382083404413459
# Simulation  90  of 237  at reduced temperature T= 2.500785135931317
# Simulation  91  of 237  at reduced temperature T= 1.3740101310860702
# Simulation  92  of 237  at reduced temperature T= 1.4190299657843153
# Simulation  93  of 237  at reduced temperature T= 2.318391181147606
# Simulation  94  of 237  at reduced temperature T= 3.178227750472817
# Simulation  95  of 237  at reduced temperature T= 1.3982222374503563
# Simulation  96  of 237  at reduced temperature T= 1.9209695845584676
# Simulation  97  of 237  at reduced temperature T= 2.492846535730004
# Simulation  98  of 237  at reduced temperature T= 2.6067519510318937
# Simulation  99  of 237  at reduced temperature T= 2.0033389881098227
# Simulation  100  of 237  at reduced temperature T= 2.701895837918977
# Simulation  101  of 237  at reduced temperature T= 2.4728262264883996
# Simulation  102  of 237  at reduced temperature T= 3.7935793549237964
# Simulation  103  of 237  at reduced temperature T= 2.2569355141168472
# Simulation  104  of 237  at reduced temperature T= 3.3188310898086866
# Simulation  105  of 237  at reduced temperature T= 2.0349314115947665
# Simulation  106  of 237  at reduced temperature T= 2.6307070628350435
# Simulation  107  of 237  at reduced temperature T= 2.6607611816740593
# Simulation  108  of 237  at reduced temperature T= 1.9304804695628512
# Simulation  109  of 237  at reduced temperature T= 1.7413175009330448
# Simulation  110  of 237  at reduced temperature T= 2.8574346812791047
# Simulation  111  of 237  at reduced temperature T= 1.9905645020415683
# Simulation  112  of 237  at reduced temperature T= 2.0324542960167036
# Simulation  113  of 237  at reduced temperature T= 2.5906564064856292
# Simulation  114  of 237  at reduced temperature T= 1.3519578649951542
# Simulation  115  of 237  at reduced temperature T= 1.589326859518183
# Simulation  116  of 237  at reduced temperature T= 2.4666293546954816
# Simulation  117  of 237  at reduced temperature T= 1.3024439387137399
# Simulation  118  of 237  at reduced temperature T= 2.5988739669401424
# Simulation  119  of 237  at reduced temperature T= 1.888045906028616
# Simulation  120  of 237  at reduced temperature T= 2.8142254238476303
# Simulation  121  of 237  at reduced temperature T= 1.901886963278042
# Simulation  122  of 237  at reduced temperature T= 2.592341781400855
# Simulation  123  of 237  at reduced temperature T= 1.6454096452640519
# Simulation  124  of 237  at reduced temperature T= 2.1560548869699314
# Simulation  125  of 237  at reduced temperature T= 2.2001023397916533
# Simulation  126  of 237  at reduced temperature T= 2.678676595436534
# Simulation  127  of 237  at reduced temperature T= 2.316875224243189
# Simulation  128  of 237  at reduced temperature T= 3.029522774024375
# Simulation  129  of 237  at reduced temperature T= 2.4099036820783635
# Simulation  130  of 237  at reduced temperature T= 2.5789531794783693
# Simulation  131  of 237  at reduced temperature T= 2.503941699924852
# Simulation  132  of 237  at reduced temperature T= 3.1027435037912374
# Simulation  133  of 237  at reduced temperature T= 2.162040765980672
# Simulation  134  of 237  at reduced temperature T= 1.3145502040634653
# Simulation  135  of 237  at reduced temperature T= 2.3878671813725822
# Simulation  136  of 237  at reduced temperature T= 1.7074372673557359
# Simulation  137  of 237  at reduced temperature T= 2.0889651881993037
# Simulation  138  of 237  at reduced temperature T= 2.620087602792251
# Simulation  139  of 237  at reduced temperature T= 2.787525093247638
# Simulation  140  of 237  at reduced temperature T= 2.322632249031965
# Simulation  141  of 237  at reduced temperature T= 2.328239010477032
# Simulation  142  of 237  at reduced temperature T= 3.558765966948163
# Simulation  143  of 237  at reduced temperature T= 2.1834963359625443
# Simulation  144  of 237  at reduced temperature T= 2.751769716019511
# Simulation  145  of 237  at reduced temperature T= 2.0513061140450204
# Simulation  146  of 237  at reduced temperature T= 1.5042426255181471
# Simulation  147  of 237  at reduced temperature T= 2.6548804341487715
# Simulation  148  of 237  at reduced temperature T= 2.19984036775822
# Simulation  149  of 237  at reduced temperature T= 2.3322227216667586
# Simulation  150  of 237  at reduced temperature T= 2.4192323041459836
# Simulation  151  of 237  at reduced temperature T= 2.133899218980817
# Simulation  152  of 237  at reduced temperature T= 2.558688500569215
# Simulation  153  of 237  at reduced temperature T= 3.0257205059574828
# Simulation  154  of 237  at reduced temperature T= 1.7012819503845515
# Simulation  155  of 237  at reduced temperature T= 1.98452809906937
# Simulation  156  of 237  at reduced temperature T= 2.2455675505813497
# Simulation  157  of 237  at reduced temperature T= 2.6895690535711942
# Simulation  158  of 237  at reduced temperature T= 1.4270494927787758
# Simulation  159  of 237  at reduced temperature T= 1.9208133524236226
# Simulation  160  of 237  at reduced temperature T= 1.6503486866290569
# Simulation  161  of 237  at reduced temperature T= 1.224151670843596
# Simulation  162  of 237  at reduced temperature T= 1.7261244003706089
# Simulation  163  of 237  at reduced temperature T= 1.7190916340216251
# Simulation  164  of 237  at reduced temperature T= 2.375393583321565
# Simulation  165  of 237  at reduced temperature T= 1.801266965154995
# Simulation  166  of 237  at reduced temperature T= 2.1790853043310814
# Simulation  167  of 237  at reduced temperature T= 1.5981468321782661
# Simulation  168  of 237  at reduced temperature T= 2.318268600881825
# Simulation  169  of 237  at reduced temperature T= 2.2538017976769673
# Simulation  170  of 237  at reduced temperature T= 2.2155879016325675
# Simulation  171  of 237  at reduced temperature T= 2.4325844095460853
# Simulation  172  of 237  at reduced temperature T= 2.8076939191744072
# Simulation  173  of 237  at reduced temperature T= 1.4334800606552616
# Simulation  174  of 237  at reduced temperature T= 2.074524056705908
# Simulation  175  of 237  at reduced temperature T= 2.7042597384923326
# Simulation  176  of 237  at reduced temperature T= 2.9742603319784617
# Simulation  177  of 237  at reduced temperature T= 2.570919712495057
# Simulation  178  of 237  at reduced temperature T= 1.5185130095977697
# Simulation  179  of 237  at reduced temperature T= 2.52984078283765
# Simulation  180  of 237  at reduced temperature T= 2.126217554703634
# Simulation  181  of 237  at reduced temperature T= 1.728441385842515
# Simulation  182  of 237  at reduced temperature T= 1.6801786069466869
# Simulation  183  of 237  at reduced temperature T= 2.2335175067116553
# Simulation  184  of 237  at reduced temperature T= 2.2950832123455105
# Simulation  185  of 237  at reduced temperature T= 1.9203547304555142
# Simulation  186  of 237  at reduced temperature T= 2.5011358217478117
# Simulation  187  of 237  at reduced temperature T= 2.243165188145754
# Simulation  188  of 237  at reduced temperature T= 2.7977603626612524
# Simulation  189  of 237  at reduced temperature T= 2.573724643493841
# Simulation  190  of 237  at reduced temperature T= 2.6336035572629335
# Simulation  191  of 237  at reduced temperature T= 2.933568471179773
# Simulation  192  of 237  at reduced temperature T= 2.898879568106403
# Simulation  193  of 237  at reduced temperature T= 2.3745205399641067
# Simulation  194  of 237  at reduced temperature T= 2.0862772308877373
# Simulation  195  of 237  at reduced temperature T= 2.877970859468461
# Simulation  196  of 237  at reduced temperature T= 2.513444401407847
# Simulation  197  of 237  at reduced temperature T= 2.353080974454857
# Simulation  198  of 237  at reduced temperature T= 1.290619691930145
# Simulation  199  of 237  at reduced temperature T= 2.469083097379772
# Simulation  200  of 237  at reduced temperature T= 1.6913010219730367
# Simulation  201  of 237  at reduced temperature T= 2.269146287150453
# Simulation  202  of 237  at reduced temperature T= 2.543394787916623
# Simulation  203  of 237  at reduced temperature T= 2.354214310607161
# Simulation  204  of 237  at reduced temperature T= 2.512955905855566
# Simulation  205  of 237  at reduced temperature T= 2.7990806882802417
# Simulation  206  of 237  at reduced temperature T= 2.1585101173622543
# Simulation  207  of 237  at reduced temperature T= 1.5582338500175914
# Simulation  208  of 237  at reduced temperature T= 2.7162367905366183
# Simulation  209  of 237  at reduced temperature T= 2.210953472277183
# Simulation  210  of 237  at reduced temperature T= 1.829614414321727
# Simulation  211  of 237  at reduced temperature T= 2.477021199727595
# Simulation  212  of 237  at reduced temperature T= 2.8831434179609596
# Simulation  213  of 237  at reduced temperature T= 1.680270991067565
# Simulation  214  of 237  at reduced temperature T= 2.611128452437825
# Simulation  215  of 237  at reduced temperature T= 2.253895648166071
# Simulation  216  of 237  at reduced temperature T= 1.7769311609284633
# Simulation  217  of 237  at reduced temperature T= 2.0290952749739875
# Simulation  218  of 237  at reduced temperature T= 1.2840927402404687
# Simulation  219  of 237  at reduced temperature T= 2.746530091137485
# Simulation  220  of 237  at reduced temperature T= 2.3902024833340305
# Simulation  221  of 237  at reduced temperature T= 1.610997959664898
# Simulation  222  of 237  at reduced temperature T= 1.8716078625567407
# Simulation  223  of 237  at reduced temperature T= 1.9397432919439048
# Simulation  224  of 237  at reduced temperature T= 3.006492164423668
# Simulation  225  of 237  at reduced temperature T= 3.3033159746346765
# Simulation  226  of 237  at reduced temperature T= 1.9520961852462961
# Simulation  227  of 237  at reduced temperature T= 1.8801030751470316
# Simulation  228  of 237  at reduced temperature T= 1.790425097145298
# Simulation  229  of 237  at reduced temperature T= 2.17501440073775
# Simulation  230  of 237  at reduced temperature T= 2.1243044278347067
# Simulation  231  of 237  at reduced temperature T= 2.336776392345783
# Simulation  232  of 237  at reduced temperature T= 1.7616610241525221
# Simulation  233  of 237  at reduced temperature T= 2.2159803901528865
# Simulation  234  of 237  at reduced temperature T= 2.3147754858895646
# Simulation  235  of 237  at reduced temperature T= 2.826288920755567
# Simulation  236  of 237  at reduced temperature T= 2.1923644059622567
# Simulation  237  of 237  at reduced temperature T= 1.6930151209691644
